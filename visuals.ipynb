# %% [markdown]
# Average of sales by day

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#Set the seaborn theme
sns.set_style("whitegrid")

# %%
df_sales = pd.read_csv('data/db_load_files/clean_data.csv')
df_sales
# Out:
#             date  total_sales day_of_week month_name  day  year  average_temp  \
# 0     2015-09-21       233.00      Monday  September   21  2015          20.9
# 1     2015-09-22        95.80     Tuesday  September   22  2015          20.4
# 2     2015-09-23       156.50   Wednesday  September   23  2015          19.0
# 3     2015-09-24       141.80    Thursday  September   24  2015          19.9
# 4     2015-09-25      1095.15      Friday  September   25  2015          21.4
# ...          ...          ...         ...        ...  ...   ...           ...
# 2055  2021-05-07      2154.00      Friday        May    7  2021          28.0
# 2056  2021-05-08      6241.70    Saturday        May    8  2021          29.0
# 2057  2021-05-09      6611.10      Sunday        May    9  2021          22.0
# 2058  2021-05-10       946.40      Monday        May   10  2021          18.0
# 2059  2021-05-11       723.20     Tuesday        May   11  2021          19.0
#
# ...

# %%
fig_dims = (20, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="year", y="total_sales", hue="day_of_week",ax=ax, data=df_sales)
# Out:
# <AxesSubplot:xlabel='year', ylabel='total_sales'>

# %%
cat_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df2 = df_sales.groupby('day_of_week').mean().reindex(cat_days) 
df2.reset_index(inplace=True)
sns.barplot(x='day_of_week', y='total_sales', data=df2);

# %%
fig_dims = (20, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="year", y="total_sales", hue="day_type",ax=ax, data=df_sales)
# Out:
# <AxesSubplot:xlabel='year', ylabel='total_sales'>

# %%
fig_dims = (20, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="year", y="total_sales", hue="month_name",ax=ax, data=df_sales)
# Out:
# <AxesSubplot:xlabel='year', ylabel='total_sales'>

# %%
fig_dims = (20, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x="year", y="total_sales", hue="did_rain",ax=ax, data=df_sales)
# Out:
# <AxesSubplot:xlabel='year', ylabel='total_sales'>

# %%
df2 = df_sales.groupby('holiday_name').mean().sort_values(by=['total_sales'], ascending=False)
df2.reset_index(inplace=True)
sns.barplot(x='holiday_name', y='total_sales', data=df2);

# %%
df2
# Out:
#                                        holiday_name  total_sales        day  \
# 0                                          SAN JOSÉ  9456.600000  19.000000
# 1                                     VIERNES SANTO  5633.933333  16.666667
# 2                            DÍA DE LA CONSTITUCIÓN  5176.816667   6.166667
# 3                             INMACULADA CONCEPCIÓN  5151.525000   8.166667
# 4   NTRA. SRA. DE LA ALMUDENA. PATRONA DE LA CIUDAD  4854.508333   9.000000
# 5                         FIESTA NACIONAL DE ESPAÑA  4809.533333  12.000000
# 6                                  TODOS LOS SANTOS  4473.954000   1.000000
# 7                                EPIFANÍA DEL SEÑOR  4386.300000   7.000000
# 8                                FIESTA DEL TRABAJO  4320.100000   1.000000
# 9                                      JUEVES SANTO  4153.533333  15.666667
# 10                               EPIFANIA DEL SEÑOR  3940.220000   6.000000
# ...

# %%
df_sales.dropna(subset = ["holiday_name"], inplace=True)

# %%
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...
