# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
from matplotlib import rcParams
import matplotlib.pyplot as plt
# figure size in inches
rcParams['figure.figsize'] = 30,8

# %%
df_holidays = pd.read_excel ('data/db_load_files/calendario.xls')

# %%
df_holidays.head(50)
# Out:
#           Dia Dia_semana laborable / festivo / domingo festivo  \
# 0  2013-01-01     martes                               festivo
# 1  2013-01-02  miércoles                             laborable
# 2  2013-01-03     jueves                             laborable
# 3  2013-01-04    viernes                             laborable
# 4  2013-01-05     sábado                                sábado
# 5  2013-01-06    domingo                               domingo
# 6  2013-01-07      lunes                               festivo
# 7  2013-01-08     martes                             laborable
# 8  2013-01-09  miércoles                             laborable
# 9  2013-01-10     jueves                             laborable
# 10 2013-01-11    viernes                             laborable
# 11 2013-01-12     sábado                                sábado
# 12 2013-01-13    domingo                               domingo
# 13 2013-01-14      lunes                             laborable
# 14 2013-01-15     martes                             laborable
# 15 2013-01-16  miércoles                             laborable
# 16 2013-01-17     jueves                             laborable
# 17 2013-01-18    viernes                             laborable
# 18 2013-01-19     sábado                                sábado
# 19 2013-01-20    domingo                               domingo
# 20 2013-01-21      lunes                             laborable
# 21 2013-01-22     martes                             laborable
# 22 2013-01-23  miércoles                             laborable
# 23 2013-01-24     jueves                             laborable
# 24 2013-01-25    viernes                             laborable
# 25 2013-01-26     sábado                                sábado
# 26 2013-01-27    domingo                               domingo
# 27 2013-01-28      lunes                             laborable
# 28 2013-01-29     martes                             laborable
# 29 2013-01-30  miércoles                             laborable
# 30 2013-01-31     jueves                             laborable
# 31 2013-02-01    viernes                             laborable
# 32 2013-02-02     sábado                                sábado
# 33 2013-02-03    domingo                               domingo
# 34 2013-02-04      lunes                             laborable
# 35 2013-02-05     martes                             laborable
# 36 2013-02-06  miércoles                             laborable
# 37 2013-02-07     jueves                             laborable
# 38 2013-02-08    viernes                             laborable
# 39 2013-02-09     sábado                                sábado
# 40 2013-02-10    domingo                               domingo
# 41 2013-02-11      lunes                             laborable
# 42 2013-02-12     martes                             laborable
# 43 2013-02-13  miércoles                             laborable
# 44 2013-02-14     jueves                             laborable
# 45 2013-02-15    viernes                             laborable
# 46 2013-02-16     sábado                                sábado
# 47 2013-02-17    domingo                               domingo
# 48 2013-02-18      lunes                             laborable
# 49 2013-02-19     martes                             laborable
#
#      Tipo de Festivo          Festividad
# 0   Festivo nacional           Año Nuevo
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
# 5                NaN                 NaN
# 6   Festivo nacional  Epifania del Señor
# 7                NaN                 NaN
# 8                NaN                 NaN
# 9                NaN                 NaN
# 10               NaN                 NaN
# 11               NaN                 NaN
# 12               NaN                 NaN
# 13               NaN                 NaN
# 14               NaN                 NaN
# 15               NaN                 NaN
# 16               NaN                 NaN
# 17               NaN                 NaN
# 18               NaN                 NaN
# 19               NaN                 NaN
# 20               NaN                 NaN
# 21               NaN                 NaN
# 22               NaN                 NaN
# 23               NaN                 NaN
# 24               NaN                 NaN
# 25               NaN                 NaN
# 26               NaN                 NaN
# 27               NaN                 NaN
# 28               NaN                 NaN
# 29               NaN                 NaN
# 30               NaN                 NaN
# 31               NaN                 NaN
# 32               NaN                 NaN
# 33               NaN                 NaN
# 34               NaN                 NaN
# 35               NaN                 NaN
# 36               NaN                 NaN
# 37               NaN                 NaN
# 38               NaN                 NaN
# 39               NaN                 NaN
# 40               NaN                 NaN
# 41               NaN                 NaN
# 42               NaN                 NaN
# 43               NaN                 NaN
# 44               NaN                 NaN
# 45               NaN                 NaN
# 46               NaN                 NaN
# 47               NaN                 NaN
# 48               NaN                 NaN
# 49               NaN                 NaN

# %%
df_holidays.dtypes
# Out:
# Dia                                      datetime64[ns]
# Dia_semana                                       object
# laborable / festivo / domingo festivo            object
# Tipo de Festivo                                  object
# Festividad                                       object
# dtype: object

# %%
df_holidays.columns
# Out:
# Index(['Dia', 'Dia_semana', 'laborable / festivo / domingo festivo',
#        'Tipo de Festivo', 'Festividad'],
#       dtype='object')

# %%
df_holidays.rename(columns={'Dia': 'date','laborable / festivo / domingo festivo': 'day_type', 'Festividad': 'holiday_name', 'Tipo de Festivo':'holiday_type' }, inplace=True)

# %%
del df_holidays['Dia_semana']

# %%
df_holidays.sample(60)
# Out:
#            date   day_type      holiday_type        holiday_name
# 1096 2016-01-02     sábado               NaN                 NaN
# 1403 2016-11-04  laborable               NaN                 NaN
# 2995 2021-03-15  laborable               NaN                 NaN
# 843  2015-04-24  laborable               NaN                 NaN
# 1389 2016-10-21  laborable               NaN                 NaN
# 1963 2018-05-18  laborable               NaN                 NaN
# 468  2014-04-14  laborable               NaN                 NaN
# 2389 2019-07-18  laborable               NaN                 NaN
# 2033 2018-07-27  laborable               NaN                 NaN
# 2996 2021-03-16  laborable               NaN                 NaN
# 930  2015-07-20  laborable               NaN                 NaN
# 2832 2020-10-03     sábado               NaN                 NaN
# 2070 2018-09-02    domingo               NaN                 NaN
# 1811 2017-12-17    domingo               NaN                 NaN
# 2644 2020-03-29    domingo               NaN                 NaN
# 818  2015-03-30  laborable               NaN                 NaN
# 2260 2019-03-11  laborable               NaN                 NaN
# 223  2013-08-12  laborable               NaN                 NaN
# 1099 2016-01-05  laborable               NaN                 NaN
# 2501 2019-11-07  laborable               NaN                 NaN
# 3113 2021-07-11    domingo               NaN                 NaN
# 1759 2017-10-26  laborable               NaN                 NaN
# 1550 2017-03-31  laborable               NaN                 NaN
# 2554 2019-12-30  laborable               NaN                 NaN
# 303  2013-10-31  laborable               NaN                 NaN
# 2559 2020-01-04     sábado               NaN                 NaN
# 2307 2019-04-27     sábado               NaN                 NaN
# 3083 2021-06-11  laborable               NaN                 NaN
# 2492 2019-10-29  laborable               NaN                 NaN
# 2266 2019-03-17    domingo               NaN                 NaN
# 2581 2020-01-26    domingo               NaN                 NaN
# 1074 2015-12-11  laborable               NaN                 NaN
# 2597 2020-02-11  laborable               NaN                 NaN
# 2301 2019-04-21    domingo               NaN                 NaN
# 2142 2018-11-13  laborable               NaN                 NaN
# 1188 2016-04-03    domingo               NaN                 NaN
# 2122 2018-10-24  laborable               NaN                 NaN
# 2282 2019-04-02  laborable               NaN                 NaN
# 801  2015-03-13  laborable               NaN                 NaN
# 767  2015-02-07     sábado               NaN                 NaN
# 2965 2021-02-13     sábado               NaN                 NaN
# 2502 2019-11-08  laborable               NaN                 NaN
# 1100 2016-01-06    festivo  Festivo nacional  Epifania del Señor
# 2022 2018-07-16  laborable               NaN                 NaN
# 1147 2016-02-22  laborable               NaN                 NaN
# 423  2014-02-28  laborable               NaN                 NaN
# 1132 2016-02-07    domingo               NaN                 NaN
# 1288 2016-07-12  laborable               NaN                 NaN
# 1984 2018-06-08  laborable               NaN                 NaN
# 3090 2021-06-18  laborable               NaN                 NaN
# 1606 2017-05-26  laborable               NaN                 NaN
# 2027 2018-07-21     sábado               NaN                 NaN
# 2064 2018-08-27  laborable               NaN                 NaN
# 1543 2017-03-24  laborable               NaN                 NaN
# 2450 2019-09-17  laborable               NaN                 NaN
# 3274 2021-12-19    domingo               NaN                 NaN
# 2599 2020-02-13  laborable               NaN                 NaN
# 1898 2018-03-14  laborable               NaN                 NaN
# 1095 2016-01-01    festivo  Festivo nacional           Año Nuevo
# 371  2014-01-07  laborable               NaN                 NaN

# %%
mask = (df_holidays['date'] > '2015-09-20') & (df_holidays['date'] <= '2021-05-11')

# %%
new_df_holidays = df_holidays.loc[mask]

# %%
new_df_holidays
# Out:
#            date   day_type holiday_type holiday_name
# 993  2015-09-21  laborable          NaN          NaN
# 994  2015-09-22  laborable          NaN          NaN
# 995  2015-09-23  laborable          NaN          NaN
# 996  2015-09-24  laborable          NaN          NaN
# 997  2015-09-25  laborable          NaN          NaN
# ...         ...        ...          ...          ...
# 3048 2021-05-07  laborable          NaN          NaN
# 3049 2021-05-08     sábado          NaN          NaN
# 3050 2021-05-09    domingo          NaN          NaN
# 3051 2021-05-10  laborable          NaN          NaN
# 3052 2021-05-11  laborable          NaN          NaN
#
# [2060 rows x 4 columns]

# %%
#List all my missing dates
pd.date_range(start = '2015-09-21', end = '2021-05-11' ).difference(new_df_holidays.date)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
new_df_holidays = new_df_holidays.set_index("date")
new_df_holidays
# Out:
#              day_type holiday_type holiday_name
# date
# 2015-09-21  laborable          NaN          NaN
# 2015-09-22  laborable          NaN          NaN
# 2015-09-23  laborable          NaN          NaN
# 2015-09-24  laborable          NaN          NaN
# 2015-09-25  laborable          NaN          NaN
# ...               ...          ...          ...
# 2021-05-07  laborable          NaN          NaN
# 2021-05-08     sábado          NaN          NaN
# 2021-05-09    domingo          NaN          NaN
# 2021-05-10  laborable          NaN          NaN
# 2021-05-11  laborable          NaN          NaN
#
# [2060 rows x 3 columns]

# %%
new_df_holidays.index.is_all_dates
# Out:
# <ipython-input-51-46e86d0e768b>:1: FutureWarning: Index.is_all_dates is deprecated, will be removed in a future version.  check index.inferred_type instead
#   new_df_holidays.index.is_all_dates
# True

# %%
pd.infer_freq(new_df_holidays.index)
# Out:
# 'D'

# %%
new_df_holidays.day_type.unique()
# Out:
# array(['laborable', 'sábado', 'domingo', 'festivo'], dtype=object)

# %%
new_df_holidays.holiday_type.unique()
# Out:
# array([nan, 'Festivo nacional', 'Festivo local de la ciudad de Madrid',
#        'Festivo de la comunidad de Madrid',
#        'Festivo de la Comunidad de Madrid'], dtype=object)

# %%
new_df_holidays.holiday_name.unique()
# Out:
# array([nan, 'Fiesta Nacional de España', 'Todos los Santos',
#        'Ntra. Sra. de la Almudena. Patrona de la ciudad',
#        'Día de la Constitución', 'Inmaculada Concepción',
#        'Natividad del Señor', 'Año Nuevo', 'Epifania del Señor',
#        'Jueves Santo', 'Viernes Santo', 'Fiesta del Trabajo',
#        'Dos de Mayo. Fiesta de la Comunidad de Madrid',
#        'San Isidro Labrador', 'Santiago Apostol', 'Asuncion de la Virgen',
#        'San Jose', 'Epifanía del Señor',
#        'Fiesta de la Comunidad de Madrid', 'Día de Todos los Santos',
#        'San José'], dtype=object)

# %%
new_df_holidays.to_csv("data/raw_data/holidays_clean.csv", index=True)
